# %% [markdown]
# faceted hist:
# https://seaborn.pydata.org/examples/faceted_histogram.html

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Introduction to the Dataset

# %% [markdown]
# This report explores the Global Development CSV Library hosted on the CORGIS Dataset Project at the URL below:
# https://think.cs.vt.edu/corgis/csv/global_development/global_development.html
#
# This data was collected by the World Bank.  It contains country-level information on various attributes related to each country's geography and demographics, along with indicators of health and infrastructure development.  The data spans the period from 1980 - 2013, with the reporting frequency being annual.

# %%
data = pd.read_csv('global_development.csv')

# %%
data.head()
# Out:
#    Agricultural Land  Agricultural Land Percent  Arable Land  \
# 0           669030.0                   7.357225     1.827821
# 1           663960.0                   7.301471     1.818526
# 2           658890.0                   7.245717     1.810120
# 3           662760.0                   7.288275     1.789779
# 4           666640.0                   7.330943     1.773217
#
#    Arable Land Percent  Birth Rate Country  Death Rate  Fertility Rate  \
# 0             4.879744        15.4  Canada         7.0           1.754
# 1             4.918123        15.4  Canada         7.1           1.740
# 2             4.956502        15.3  Canada         7.0           1.700
# 3             4.960241        15.1  Canada         7.1           1.690
# 4             4.963870        15.0  Canada         7.0           1.680
#
#    Land Area  Life Expectancy at Birth, Female  ...   Population Growth  \
# 0  9093510.0                             78.59  ...            0.997669
# 1  9093510.0                             78.73  ...            1.293245
# 2  9093510.0                             79.11  ...            1.240595
# 3  9093510.0                             79.23  ...            1.205555
# 4  9093510.0                             79.55  ...            1.002812
#
#    Rural Population  Rural Population Growth  Surface Area  Telephone Lines  \
# 0         5918004.0                 0.833712     9984670.0        9595000.0
# 1         5985198.0                 1.129019     9984670.0        9979000.0
# 2         6047712.0                 1.039060     9984670.0       10294500.0
# 3         6080235.0                 0.536333     9984670.0       10335442.0
# 4         6100530.0                 0.333231     9984670.0       10468344.0
#
#    Telephone Lines per 100 People  Total Population  Urban Population Percent  \
# 0                       39.562351        24277000.0                    75.623
# 1                       40.712240        24593000.0                    75.663
# 2                       41.570761        24900000.0                    75.712
# 3                       41.320642        25202000.0                    75.874
# 4                       41.429346        25456000.0                    76.035
#
#    Urban Population Percent Growth  Year
# 0                         1.050578  1980
# 1                         1.346126  1981
# 2                         1.305333  1982
# 3                         1.419293  1983
# 4                         1.214785  1984
#
# [5 rows x 25 columns]

# %%
data.describe(include='all')
# Out:
#         Agricultural Land  Agricultural Land Percent  Arable Land  \
# count        6.426000e+03                6426.000000  6426.000000
# unique                NaN                        NaN          NaN
# top                   NaN                        NaN          NaN
# freq                  NaN                        NaN          NaN
# mean         1.657112e+06                  37.931998     0.250677
# std          5.122268e+06                  20.693752     0.272452
# min          7.000000e+00                   0.410256     0.000119
# 25%          1.384000e+04                  21.184470     0.099707
# 50%          9.269333e+04                  38.245197     0.200077
# 75%          4.528150e+05                  53.242807     0.323774
# max          4.924515e+07                  91.160436     3.055343
#
#         Arable Land Percent   Birth Rate      Country   Death Rate  \
# count           6426.000000  6426.000000         6426  6426.000000
# unique                  NaN          NaN          189          NaN
# top                     NaN          NaN  Philippines          NaN
# freq                    NaN          NaN           34          NaN
# mean              13.061979    28.547278          NaN     9.867670
# std               12.822072    12.239007          NaN     4.659770
# min                0.043141     7.700000          NaN     1.042000
# 25%                3.320740    17.749094          NaN     6.600000
# 50%                9.721130    27.757349          NaN     8.902500
# 75%               17.679780    39.078750          NaN    11.869558
# max               73.388646    56.269000          NaN    48.922000
#
#         Fertility Rate     Land Area  Life Expectancy at Birth, Female  \
# count      6426.000000  6.426000e+03                       6426.000000
# unique             NaN           NaN                               NaN
# top                NaN           NaN                               NaN
# freq               NaN           NaN                               NaN
# mean          3.890304  4.462811e+06                         66.979744
# std           1.879436  1.377176e+07                         11.340785
# min           1.076000  1.800000e+02                         27.323000
# 25%           2.191759  4.239000e+04                         58.213007
# 50%           3.503799  2.981700e+05                         70.169658
# 75%           5.544500  1.246700e+06                         76.252750
# max           9.223000  1.298204e+08                         86.440000
#
#            ...       Population Growth  Rural Population  \
# count      ...             6426.000000      6.328000e+03
# unique     ...                     NaN               NaN
# top        ...                     NaN               NaN
# freq       ...                     NaN               NaN
# mean       ...                1.862876      6.815012e+07
# std        ...                1.424117      2.096894e+08
# min        ...               -7.597309      0.000000e+00
# 25%        ...                0.910546      8.222148e+05
# 50%        ...                1.867816      4.385654e+06
# 75%        ...                2.653923      1.920352e+07
# max        ...               17.483235      2.124164e+09
#
#         Rural Population Growth  Surface Area  Telephone Lines  \
# count               6426.000000  6.426000e+03     6.426000e+03
# unique                      NaN           NaN              NaN
# top                         NaN           NaN              NaN
# freq                        NaN           NaN              NaN
# mean                   0.836405  4.604248e+06     2.496955e+07
# std                    1.947775  1.421104e+07     9.995439e+07
# min                  -18.845386  1.800000e+02     0.000000e+00
# 25%                   -0.095717  4.309000e+04     4.199250e+04
# 50%                    0.958085  3.013400e+05     3.518650e+05
# 75%                    1.968481  1.246700e+06     3.725384e+06
# max                   15.153588  1.343247e+08     1.261054e+09
#
#         Telephone Lines per 100 People  Total Population  \
# count                      6426.000000      6.426000e+03
# unique                             NaN               NaN
# top                                NaN               NaN
# freq                               NaN               NaN
# mean                         13.709439      1.971216e+08
# std                          17.163466      6.774747e+08
# min                           0.000000      5.315400e+04
# 25%                           0.942396      2.420536e+06
# 50%                           5.200926      9.793784e+06
# 75%                          21.069157      4.918105e+07
# max                          74.762467      7.043106e+09
#
#         Urban Population Percent  Urban Population Percent Growth         Year
# count                6426.000000                      6426.000000  6426.000000
# unique                       NaN                              NaN          NaN
# top                          NaN                              NaN          NaN
# freq                         NaN                              NaN          NaN
# mean                   49.794711                         2.938491  1995.018519
# std                    23.848442                         2.204711    11.122234
# min                     3.480000                        -7.102666  1960.000000
# 25%                    29.752000                         1.346809  1987.000000
# 50%                    47.684000                         2.840338  1995.000000
# 75%                    71.130750                         4.132614  2004.000000
# max                   100.000000                        48.938941  2013.000000
#
# [11 rows x 25 columns]

# %% [markdown]
# All features in the dataset, along with their data types are shown below:

# %%
data.dtypes
# Out:
# Agricultural Land                               float64
# Agricultural Land Percent                       float64
# Arable Land                                     float64
# Arable Land Percent                             float64
# Birth Rate                                      float64
# Country                                          object
# Death Rate                                      float64
# Fertility Rate                                  float64
# Land Area                                       float64
# Life Expectancy at Birth, Female                float64
# Life Expectancy at Birth, Male                  float64
# Life Expectancy at Birth, Total                 float64
# Mobile Cellular Subscriptions                   float64
# Mobile Cellular Subscriptions per 100 People    float64
# Population Density                              float64
# Population Growth                               float64
# Rural Population                                float64
# Rural Population Growth                         float64
# Surface Area                                    float64
# Telephone Lines                                 float64
# Telephone Lines per 100 People                  float64
# Total Population                                float64
# Urban Population Percent                        float64
# Urban Population Percent Growth                 float64
# Year                                              int64
# dtype: object

# %% [markdown]
# The features can be grouped into the following categories (excluding `Country` and `Year`):
#
# 1. Geographic Features
#     * Agricultural Land
#     * Agricultural Land Percent
#     * Arable Land
#     * Arable Land Percent
#     * Land Area
#     * Surface Area
#
# 2. Demographic features
#     * Birth Rate
#     * Death Rate
#     * Fertility Rate
#     * Population Density
#     * Population Growth
#     * Total Population
#     * Rural Population
#     * Rural Population Growth
#     * Urban Population Percent
#     * Urban Population Percent Growth
#
# 3. Health-related features
#     * Life Expectancy at Birth, Female
#     * Life Expectancy at Birth, Male
#     * Life Expectancy at Birth, Total
#
# 4. Infrastructure/development-related features
#     * Mobile Cellular Subscriptions
#     * Mobile Cellular Subscriptions per 100 People
#     * Telephone Lines
#     * Telephone Lines per 100 People

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# A simple data quality check can be constructed based on the number of mobile cellular subscriptions reported in the dataset.  According to Wikipedia, the world's first commercial cellular network was launched in Japan in 1979.  Next, commercial cellular service was launched by Nordic Mobile Telephone in Denmark, Finland, Norway, and Sweden in 1981.
#
# The plot below shows the total number of cellular subscriptions per year in the world:

# %%
# Group by year and sum cellular subscriptions
grp_by_cell = data.groupby(by='Year', as_index=False)[['Mobile Cellular Subscriptions']].sum()
# Only retain data up to 1996
grp_by_cell = grp_by_cell[grp_by_cell.Year <= 1996]

# %%
sns.set(style="ticks", rc={'figure.figsize':(15,9)}, font_scale=1.5)
ax = sns.barplot(x='Year', y='Mobile Cellular Subscriptions', data=grp_by_cell, color="salmon", saturation=.8)
ax.set(ylabel='Total Number of Cellular Subscriptions')
# show only alternate x axis tick labels
for label in ax.xaxis.get_ticklabels()[1::2]:
    label.set_visible(False)
plt.title('Data quality check - mobile subscriptions up to 1996')

# %%
# Group by year and sum cellular subscriptions per 100 People
grp_by_cell2 = data.groupby(by='Year', as_index=False)[['Mobile Cellular Subscriptions per 100 People']].sum()
# Only retain data up to 1996
grp_by_cell2 = grp_by_cell2[grp_by_cell2.Year <= 1996]

# %%
sns.set(style="ticks", rc={'figure.figsize':(15,9)}, font_scale=1.5)
ax = sns.barplot(x='Year', y='Mobile Cellular Subscriptions per 100 People', data=grp_by_cell2, color="salmon", saturation=.5)
ax.set(ylabel='Total Number of Cellular Subscriptions per 100 People')
# show only alternate x axis tick labels
for label in ax.xaxis.get_ticklabels()[1::2]:
    label.set_visible(False)
plt.title('Data quality check - mobile subscriptions up to 1996')
# Out:
# Text(0.5,1,'Data quality check - mobile subscriptions up to 1996')

# %% [markdown]
# The plots above show 2 dubious patterns:
# * There are a large number of mobile cellular subscriptions prior to 1979 - which was the first year commercial cellular services were offered.
# * Even focusing on only the data post-1979, the number of subscriptions shows the dubious pattern of first decreasing and then increasing.
#
# Hence, it is reasonable to drop both columns related to mobile cellular subscriptions because the data in those columns cannot be trusted.

# %%
data.drop(['Mobile Cellular Subscriptions', 'Mobile Cellular Subscriptions per 100 People'], axis=1, inplace=True)
